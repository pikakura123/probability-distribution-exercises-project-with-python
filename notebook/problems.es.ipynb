# %% [markdown]
# # Problemas de distribución de probabilidad

# %% [markdown]
# ## Distribución binomial
#
# En teoría de la probabilidad y estadística, la distribución binomial es la distribución de probabilidad discreta que da sólo dos resultados posibles en un experimento; por ejemplo, al lanzar una moneda, puede salir cara o cruz.

# %%
from scipy.stats import binom

# Definir todas las funciones de probabilidad relacionadas con esta distribución.

def dbinom(x, size, prob = 0.5):
    """
    Calcula la estimación puntual de la distribución binomial.
    """
    result = binom.pmf(k = x, n = size, p = prob, loc = 0)

    return result

def pbinom(q, size, prob = 0.5):
    """
    Calcula el acumulado de la distribución binomial.
    """
    result = binom.cdf(k = q, n = size, p = prob, loc = 0)

    return result

def qbinom(p, size, prob = 0.5):
    """
    Calcula la función cuantil a partir de la distribución binomial.
    """
    result = binom.ppf(q = p, n = size, p = prob, loc = 0)

    return result

def rbinom(n, size, prob = 0.5):
    """
    Genera variables aleatorias a partir de la distribución binomial.
    """
    result = binom.rvs(n = size, p = prob, size = n)

    return result

# %%
# Distribución binomial(10, 0.2), dónde n = 10 es el número de ensayos y p = 0.2 es la probabilidad de éxito en un solo ensayo
import numpy as np

np.random.seed(42)

print(f"Probability that a Binomial(10, 0.2) takes the value 2: {dbinom(2, size = 10, prob = 0.2)}")
print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rbinom(2000, size = 10, prob = 0.2)}")
# Out:
# Probability that a Binomial(10, 0.2) takes the value 2: 0.30198988800000004
# Probability that a Binomial(10, 0.2) will take a value less than 2: 0.6777995263999999
# Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? 4.0
# Generate 2000 random values from a Binomial(10, 0.2) distribution: [1 4 3 ... 0 0 1]

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

size = 10
prob = 0.2
data = rbinom(2000, size = 10, prob = 0.2)

pmf = dbinom(data, size = size, prob = prob)
cdf = pbinom(data, size = size, prob = prob)
ppf = qbinom(data, size = size, prob = prob)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Ejercicio 1
#
# Escriba las funciones anteriores pero para distribuciones normales y uniformes.

# %%
# TODO

from scipy.stats import norm
from scipy.stats import uniform



def dnorm(x, mean=0, std_dev=1):
    
    result = norm.pdf(x, loc=mean, scale=std_dev)
    return result



def duniform(x, loc=0, scale=1):
   
    result = uniform.pdf(x, loc=loc, scale=scale)
    return result

#


def pnorm(q, mean=0, std_dev=1):
  
    result = norm.cdf(q, loc=mean, scale=std_dev)
    return result



def puniform(q, loc=0, scale=1):
    result = uniform.cdf(q, loc=loc, scale=scale)
    return result

#



def qnorm(p, mean=0, std_dev=1):
    result = norm.ppf(p, loc=mean, scale=std_dev)
    return result



def quniform(p, loc=0, scale=1):
    result = uniform.ppf(p, loc=loc, scale=scale)
    return result

#




def rnorm(n, mean=0, std_dev=0):
    
    result = norm.rvs(loc=mean, scale=std_dev, size=n)
    return result



def runiform(n, loc=0, scale=0):
    result = uniform.rvs(loc=loc, scale=scale, size=n)
    return result


######################################################

# %%
from scipy.stats import norm
from scipy.stats import uniform


def pnorm(q, mean=0, std_dev=1):
  
    result = norm.cdf(q, loc=mean, scale=std_dev)
    return result

pnorm(8 , 8, 3)
# Out:
# np.float64(0.5)

# %%
dnorm(3, mean=0, std_dev=1)
# Out:
# np.float64(0.0044318484119380075)

# %%
# Distribución binomial(10, 0.2), dónde n = 10 es el número de ensayos y p = 0.2 es la probabilidad de éxito en un solo ensayo
from scipy.stats import norm
from scipy.stats import uniform

np.random.seed(42)


print(f"Probability that a normal(8 ,3) takes the value 2: {dnorm(10, mean = 8, std_dev = 3)}")
print(f"Probability that a normal(8 ,3) will take a value less than 2: {pnorm(10, mean = 8, std_dev = 3)}")
print(f"Which value of a normal(8 ,3) has a cumulative probability of 0.9? {qnorm(0.5, mean = 8, std_dev = 3)}")
print(f"Generate 2000 random values from a normal(8 ,3) distribution: {rnorm(10, mean = 8, std_dev = 3)}")
# Out:
# Probability that a normal(8 ,3) takes the value 2: 0.10648266850745075
# Probability that a normal(8 ,3) will take a value less than 2: 0.7475074624530771
# Which value of a normal(8 ,3) has a cumulative probability of 0.9? 8.0
# Generate 2000 random values from a normal(8 ,3) distribution: [ 9.49014246  7.5852071   9.94306561 12.56908957  7.29753988  7.29758913
#  12.73763845 10.30230419  6.59157684  9.62768013]

# %%
norm.pdf(3, )
# Out:
# np.float64(0.0044318484119380075)

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

mean = 8
std_dev = 3
data = rnorm(2000, 8, 3)

pmf = dnorm(data, mean = mean, std_dev = std_dev)
cdf = pnorm(data, mean = mean, std_dev = std_dev)
ppf = qnorm(data, mean = mean, std_dev = std_dev)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Distribución binomial(10, 0.2), dónde n = 10 es el número de ensayos y p = 0.2 es la probabilidad de éxito en un solo ensayo
from scipy.stats import norm
from scipy.stats import uniform

np.random.seed(42)


print(f"Probability that a uniform(8 ,3) takes the value 2: {duniform(20, loc=0, scale=1)}")
print(f"Probability that a uniform(8 ,3) will take a value less than 2: {puniform(20, loc=0, scale=1)}")
print(f"Which value of a uniform(8 ,3) has a cumulative probability of 0.9? {quniform(20, loc=0, scale=1)}")
print(f"Generate 2000 random values from a uniform(8 ,3) distribution: {runiform(20, loc=0, scale=1)}")

# %%
import matplotlib.pyplot as plt
#tarea 2

np.random.seed(42)


data = runiform(10000, 0, 1)

pmf = duniform(data, loc=0, scale=1)
cdf = puniform(data, loc=0, scale=1)
ppf = quniform(data, loc=0, scale=1)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()
